# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.15.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 58.2 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.23.1-py3-none-any.whl (448 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.3/448.3 kB 48.0 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 10.2 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.3.0.post0 selenium-4.15.2 trio-0.23.1 trio-websocket-0.11.1 wsproto-1.2.0

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# On va d'abord extraire les titres des articles d'un site d'information français, nous avons choisi le site [Le Monde](https://www.lemonde.fr/)

# %%
url = 'https://www.lemonde.fr/'

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
response = requests.get(url, headers=headers)

# %%
if response.status_code == 200:
    # Utiliser Beautiful Soup pour extraire le contenu HTML de la page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Exemple : Extraire tous les titres d'articles
    titles = soup.find_all('p', class_='article__title')

    # Afficher les titres
    for title in titles:
        print(title.text.strip())
        print("\n")
else:
    print(f"La requête a échoué avec le code d'état {response.status_code}")
# Out:
# Pourquoi la quête de souveraineté numérique sur Internet menace l’hégémonie américaine
#
#
# Pourquoi Sam Altman, star de l’intelligence artificielle, a été débarqué d’OpenAI
#
#
# Black Friday : « Le pays et ses décideurs politiques balancent entre la défense du consommateur, celle de l’environnement et celle du producteur »
#
#
# « Les Français fument bien plus que leurs voisins, même si le prix de leurs cigarettes est jusqu’à deux fois plus onéreux »
#
#
# Du cartel mexicain de Sinaloa aux rues de New York : au cœur du business du fentanyl
#
#
# Bande de Gaza : avant la guerre, un territoire à l’agonie
#
#
# Comment Napoléon a conquis (et perdu) l’Europe
#
#
# Madagascar : cinq choses à savoir sur Andry Rajoelina
#
#
# Réindustrialisation : la France au milieu du gué
#
#
# Faut-il abolir l’Etat, cet horizon indépassable de nos imaginaires politiques ?
#
#
# L’Argentine, un pays dans l’impasse faute de vision politique
#
#
# Anne Hidalgo : « Pour rester fidèle à mes convictions et à mon engagement, je quitte aujourd’hui X »
#
#
# Avec « La Rivière », Dominique Marchais, cinéaste, crée une œuvre au vert originale
#
#
# « La Pérégrination vers l’Ouest » : l’une des plus belles sources du manga
#
#
# « Un maestro en huit variations : le chef d’orchestre François-Xavier Roth », un portrait inégal et frustrant sur Arte
#
#
# Annette Messager expose ses « Affaires personnelles » chez Emmaüs
#
#
# Dans le ceviche de chez Donna, à Paris, « on aime l’équilibre des ingrédients qui ne rivalisent jamais avec le goût de la sériole crue »
#
#
# Naraé Kim, bijou de pâtissière
#
#
# Au Maroc, un réveil créatif porté par une jeunesse fière et ultraconnectée
#
#
# La France buissonnière : 1 euro la pharmacie, qui dit mieux ?
#
#
# L’hôtellerie résiste à la crise de l’immobilier : « En ce moment, l’hôtellerie, c’est une sorte d’eldorado »
#
#
# Casino va étudier la vente de supermarchés et d’hypermarchés supplémentaires
#
#
# Après la « trahison » de la Russie, l’Arménie cherche de nouveaux alliés pour assurer sa sécurité
#
#
# Le Pas-de-Calais placé en vigilance orange, de nouvelles crues attendues
#
#
# Black Friday : « Le pays et ses décideurs politiques balancent entre la défense du consommateur, celle de l’environnement et celle du producteur »
#
#
# Assassinat de Samuel Paty : un premier procès pour six adolescents s’ouvre devant le tribunal pour enfants
#
#
# Face à la prolifération des meublés de type Airbnb, le gouvernement prêt à serrer la vis
#
#
# « Pour la première fois, toute l’Union européenne a enclenché la marche arrière sur l’environnement »
#
#
# Pourquoi « il est faux et anachronique de considérer le Coran comme antisémite »
#
#
# Réindustrialisation : la France au milieu du gué
#
#
# Black Friday : « Le pays et ses décideurs politiques balancent entre la défense du consommateur, celle de l’environnement et celle du producteur »
#
#
# Jamais la Palestine n’a autant souffert
#
#
# En direct, guerre Israël-Hamas : le gouvernement israélien a reçu la liste des otages devant être libérés aujourd’hui
#
#
# En direct, guerre en Ukraine : les dernières informations
#
#
# Meurtre de Thomas à Crépol : des militants d’extrême droite samedi soir à Romans-sur-Isère pour « en découdre »
#
#
# Avec la libération d’otages au compte-gouttes, le Hamas poursuit la guerre contre Israël sur le terrain psychologique
#
#
# Samuel Etienne, journaliste : « Je laisse souvent la maman prendre les décisions les moins sympas, celles qui fâchent »
#
#
# Au procès du rappeur Young Thug, ses chansons pourront être retenues contre lui
#
#
# En Amérique du Sud, un printemps « historiquement chaud » accable les populations
#
#
# « Finale des championnats d’Europe. Arrivée au milieu, je déchire mon dossard. Le début d’une descente aux enfers »
#
#
# Assassinat de Samuel Paty : un premier procès pour six adolescents s’ouvre devant le tribunal pour enfants

# %% [markdown]
# On va maintenant extraire les titres des articles d'un site d'information international, nous avons choisi le site américain [The Washington Post](https://www.washingtonpost.com/)

# %%
url2 = 'https://www.washingtonpost.com/'

# %%
response2 = requests.get(url2, headers=headers)

# %%
if response2.status_code == 200:
    # Utiliser Beautiful Soup pour extraire le contenu HTML de la page
    soup = BeautifulSoup(response2.content, 'html.parser')

    # Exemple : Extraire tous les titres d'articles
    titles = soup.find_all('h2', class_='wpds-c-iiQaMf wpds-c-iiQaMf-ihElTZa-css')
    titles = titles + soup.find_all('h2', class_='wpds-c-iiQaMf wpds-c-iiQaMf-ibYgSwf-css')

    # Afficher les titres
    for title in titles:
        print(title.text.strip())
        print("\n")
else:
    print(f"La requête a échoué avec le code d'état {response.status_code}")
# Out:
# 4-year-old is symbol of hope after ‘terrible trauma’
#
#
# Improving relationships is hard. A couples therapist recommends these books.
#
#
# How to shop for kids without adding to the mountain of plastic
#
#
# A Saturday so rich in spellbinding fourth downs, it deserves some awards
#
#
# 7 easy recipes for when you can’t be bothered to cook (much)
#
#
# College football coaching vacancies: Who’s in, who’s out
#
#
# FBS newcomer James Madison is bowl-bound after other teams fail to reach 6-win mark
#
#
# A doctor tried to renew his passport. Now he’s no longer a citizen.
#
#
# The new dating app etiquette
#
#
# OpenAI and X: Promises of populist technology, shaped by a single man
#
#
# How one rabid kitten triggered intensive effort to contain deadly virus
#
#
# What we actually know about aliens, according to science
#
#
# Three Palestinian students injured in Vermont shooting
#
#
# Hijacking attempt on Israel-linked ship thwarted by U.S. Navy
#
#
# A 5-step prescription to combat loneliness during the holidays
#
#
# This lawsuit could disrupt the U.S. tax system. Key facts are in dispute.
#
#
# Old train routes are getting recycled into new trail networks
#
#
# Seven Montgomery schools are named after enslavers. That could change.
#
#
# Does firing an NFL coordinator midseason actually help a team?
#
#
# 11 can’t miss concerts in the D.C. area in December
#
#
# This boy was born without an immune system. Gene therapy rebuilt it.
#
#
# What to know from NFL Week 12: The Eagles’ weaknesses are irrelevant
#
#
# Keyword
#
#
# On the Record
#
#
# Mini Meta Crossword
#
#
# Sudoku
#
#
# ‘I know what I saw’: The soldier’s story that made many Grenadians suspicious of the U.S. government
#
#
# Deep Reads: Football bonded them. Then it tore them apart.
#
#
# Erik Wemple answers your questions on the media
#
#
# Election 2024: The Post’s Political Roundtable with Ashley Parker, Brianna Tucker and Marianne LeVine
#
#
# Israel-Gaza war live updates: Israel, Hamas appear open to extending pause; aid agencies rush deliveries to Gaza
#
#
# This lawsuit could disrupt the U.S. tax system. Key facts are in dispute.
#
#
# The Trump Trials: Hot bench and cold turkey
#
#
# I thought I was having an anxiety attack. It was a ‘widowmaker.’
#
#
# Univision anchor Jorge Ramos rebukes network for not challenging Trump
#
#
# Democratic presidential candidate Dean Phillips announces he won’t run for reelection in House
#
#
# CEO of pro-DeSantis super PAC resigns amid rising tensions
#
#
# Donations to GOP drop as worries mount about the party’s finances
#
#
# Ask Amy: Should my son legalize his custody arrangement with volatile mom?
#
#
# Miss Manners: Saying ‘thoughts and prayers’ to an atheist
#
#
# Ask Sahaj: Spending time with my family feels ‘performative’ and ‘oppressive’
#
#
# I have chronic fatigue syndrome, and my young daughter is exhausting
#
#
# Just how germy is that shopping cart? We asked scientists.
#
#
# What a mystery illness in dogs could mean for holiday pet care
#
#
# 52 children got lead poisoning from fruit pouches. Here’s what to know.
#
#
# Nearly 1 in 5 adolescents now using melatonin to sleep, researchers say
#
#
# Biden to skip world leaders’ summit at COP28 climate talks in Dubai
#
#
# After the pandemic, Americans are flying again in force. Here’s why that’s a problem.
#
#
# Wild turkeys are disappearing — but no one is sure why
#
#
# States must target transportation carbon emission cuts under new federal rule
#
#
# Snow in the Plains and Midwest to slow post-Thanksgiving travel
#
#
# Snowstorm plastering Rockies will hit Plains amid post-Thanksgiving travel
#
#
# Soaking Mid-Atlantic storm brings drought relief
#
#
# A hungry beaver is chomping on the Tidal Basin’s cherry trees
#
#
# Four rules for no-regrets Black Friday shopping
#
#
# Taking holiday family portraits can be tricky. Here’s how to get great ones.
#
#
# These look like prizewinning photos. They’re AI fakes.
#
#
# Elon Musk says SpaceX will soon be ready for third flight of Starship
#
#
# Derek Chauvin stabbed in federal prison in Arizona, says Minnesota AG
#
#
# Carters’ journey highlights tough questions about when to choose hospice
#
#
# 34 pro-Palestinian protesters arrested for disrupting Macy’s parade, police say
#
#
# Buttigieg promises to investigate wheelchair incident from viral video
#
#
# Russia held these Ukrainian teens captive. Their testimonies could be used against Putin.
#
#
# Dutch election shows far right rising and reshaping Europe
#
#
# Emmanuel Le Roy Ladurie, historian of the downtrodden, dies at 94
#
#
# Europe’s far right goes mainstream
#
#
# Paul Lynch’s ‘Prophet Song’ wins the Booker Prize
#
#
# Fact-checking ‘The Crown’: Did Dodi propose to Diana the night they died?
#
#
# New John Singer Sargent show unites Madame X and Dr. Pozzi. Sparks fly.
#
#
# The best movies of 2023 so far
#
#
# Virginia localities sue pharmaceutical giants over insulin costs
#
#
# Kids keep missing school in Virginia. Leaders are looking to curb that.
#
#
# Punctuation cleanup in the checkout aisle, please
#
#
# Microplastics were found in D.C. rivers. Researchers want to find why.
#
#
# D.C.-area forecast: A winter chill for November’s waning days
#
#
# The 36 best things to do in D.C. this weekend and next week
#
#
# ‘Zoom fatigue’ may take toll on the brain and the heart, researchers say
#
#
# Carters’ journey highlights tough questions about when to choose hospice
#
#
# Elon Musk says SpaceX will soon be ready for third flight of Starship
#
#
# Send your name to space via NASA’s ‘Message in a Bottle’
#
#
# A Saturday so rich in spellbinding fourth downs, it deserves some awards
#
#
# Steelers get moving on offense, sort of, to beat Joe Burrow-less Bengals
#
#
# Capitals begin road trip with changes to struggling power play
#
#
# James Madison is bowl-bound after getting help from other FBS programs
#
#
# Colleges refocus on career services as students seek return on degrees
#
#
# The viral $16 McDonald’s meal that may explain voter anger at Biden
#
#
# How to be a financially savvy holiday shopper
#
#
# Binance crypto chief Changpeng Zhao pleads guilty to federal charges

# %% [markdown]
# On va maintenant extraire les commentaires d'une vidéo [Youtube](https://www.youtube.com/) dont le lien est passé en paramètres

# %%
def youtube_scraping(link) :

    l=list()
    o={}

    target_url = [link]

    s = Service(r"C:\Program Files (x86)\chromedriver.exe")

    for url in target_url:
        driver = webdriver.Chrome(service=s)
        driver.get(url)

    driver.maximize_window()
    time.sleep(4)
    driver.execute_script("window.scrollTo(0, 1000);")
    for i in range(0,6):
        time.sleep(2)
        driver.execute_script("window.scrollTo(0, 10000);")

    comments_section = driver.find_element(By.XPATH,'//*[@id="comments"]')

    comments_html = comments_section.get_attribute('innerHTML')

    soup = BeautifulSoup(comments_html, 'html.parser')

    # extraction du texte des commentaires
    comments = [comment.text for comment in soup.find_all('yt-formatted-string', {'class': 'style-scope ytd-comment-renderer'})]

    # affichage des commentaires
    for comment in comments :
        print(comment)
        print("\n")
    driver.close()

youtube_scraping("https://www.youtube.com/watch?v=6SCQo9oc5dM")
# Out:
# ---------------------------------------------------------------------------
# NoSuchDriverException                     Traceback (most recent call last)
# <ipython-input-9-e16e6b67f7f8> in <cell line: 36>()
#      34     driver.close()
#      35
# ---> 36 youtube_scraping("https://www.youtube.com/watch?v=6SCQo9oc5dM")
#
# <ipython-input-9-e16e6b67f7f8> in youtube_scraping(link)
#       9
#      10     for url in target_url:
# ---> 11         driver = webdriver.Chrome(service=s)
#      12         driver.get(url)
#      13
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, options, service, keep_alive)
#      43         options = options if options else Options()
#      44
# ---> 45         super().__init__(
#      46             DesiredCapabilities.CHROME["browserName"],
#      47             "goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      49         self.service = service
#      50
# ---> 51         self.service.path = DriverFinder.get_path(self.service, options)
#      52
#      53         self.service.start()
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/common/driver_finder.py in get_path(service, options)
#      42
#      43         if path is None or not Path(path).is_file():
# ---> 44             raise NoSuchDriverException(f"Unable to locate or obtain driver for {options.capabilities['browserName']}")
#      45
#      46         return path
#
# NoSuchDriverException: Message: Unable to locate or obtain driver for chrome; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location
